# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 1: Mining Twitter: Exploring Trending Topics, Discovering What People Are Talking About, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application. There are four primary identifiers you'll need to note for an OAuth 1.0A workflow: consumer key, consumer secret, access token, and access token secret. Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.
#
# <img src="files/resources/ch01-twitter/images/Twitter-AppCredentials.png" width="600px">

# %% [markdown]
# If you are taking advantage of the virtual machine experience for this chapter that is powered by Vagrant, you should just be able to execute the code in this notebook without any worries whatsoever about installing dependencies. If you are running the code from your own development envioronment, however, be advised that these examples in this chapter take advantage of a Python package called [twitter](https://github.com/sixohsix/twitter) to make API calls. You can install this package in a terminal with [pip](https://pypi.python.org/pypi/pip) with the command `pip install twitter`, preferably from within a [Python virtual environment](https://pypi.python.org/pypi/virtualenv).

# %% [markdown]
# Once installed, you should be able to open up a Python interpreter (or better yet, your [IPython](http://ipython.org/) interpreter) and get rolling.

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

# XXX: Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = 'LUDiw6UJwbcOpJxCUMwprQTjz'
CONSUMER_SECRET ='eRZxk3NObvhfdRPlqSZnjcAnilPCRkaV16616mI86Fzi6ENi35'
OAUTH_TOKEN = '1150071104-cBt0I6tLwweKg5LlMHRSN8sZS22lXsXPCGOpW4Z'
OAUTH_TOKEN_SECRET = 'aulODA2dhSCLgyiTLJ74adyPtJ2mShhhfWUx9FJkpJzXa'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print twitter_api
# Out:
# <twitter.api.Twitter object at 0x106bc81d0>

# %%
results = twitter_api.statuses.user_timeline(screen_name = 'crunchbase', count=300)
#results = twitter.statuses.user_timeline(screen_name="billybob")


d = {}

print len(results)
#-----------------------------------------------------------------------
# loop through each status item, and print its content.
#-----------------------------------------------------------------------
for status in results:
    print "(%s) %s" % (status["created_at"], status["text"].encode("ascii", "ignore"))
    d[status["created_at"]] = status["text"].encode("ascii", "ignore")
# Out:
# 200
# (Wed Nov 25 20:42:41 +0000 2015) @_adonisk Hey Adonis! Can you send us an email from the address you want to unsubscribe with? We're happy to help! feedback@crunchbase.com
# (Wed Nov 25 20:40:52 +0000 2015) @primdahl Hey Morton! Can you send us an email from the address you want to unsubscribe from? feedback@crunchbase.com Thanks!
# (Wed Nov 25 16:29:14 +0000 2015) Today's #CBDaily: $2.2B in 203 rounds added &amp; more! https://t.co/MNUxay2bsB https://t.co/EIf130FjF8
# (Tue Nov 24 18:31:02 +0000 2015) Today's #CBDaily: $2.1B in 354 rounds added &amp; more! https://t.co/AEaryWD0Vk https://t.co/mHh7rUSNpu
# (Mon Nov 23 20:54:02 +0000 2015) Great to see @nyftlab featuring #FemaleFounders! Find application info for the new batch https://t.co/it7bO5J3tK https://t.co/FlDa4vZPu0
# (Mon Nov 23 15:55:14 +0000 2015) Today's #CBDaily: $920M in 446 rounds added &amp; more! https://t.co/AEaryWD0Vk https://t.co/eLTAuPdtpo
# (Sun Nov 22 23:07:38 +0000 2015) @julian_dunn Hey Julian, thanks for the alert! Can you send us an email about this? feedback@crunchbase.com Thanks!
# (Sun Nov 22 23:07:06 +0000 2015) @prdonahue Hey Patrick! Can you email us with more details? feedback@crunchbase.com We'd be happy to help!
# (Sat Nov 21 18:38:22 +0000 2015) RT @lipmanb: $135 Million raised today by 19 startups. Data from @Crunchbase. - #VentureCapital #VC #Startup #entreprenuership https://t.co
# (Sat Nov 21 04:35:54 +0000 2015) RT @franzisbecker: Thought-provoking and Incredible overview of The State of European Tech by @atomico https://t.co/xM421W59VO
# (Sat Nov 21 04:31:09 +0000 2015) RT @EzaroMedia: Interesting analysis based on CB data. It is somewhat surprising to find so few of these published: https://t.co/aLEt939alf
# (Fri Nov 20 16:57:51 +0000 2015) @imCommunityMgr Hey Chrissy! Can you email us more details? Browser, device, version, links, we'd love to help! Feedback@crunchbase.com
# (Fri Nov 20 15:32:40 +0000 2015) Today's #CBDaily: $442M in 216 rounds added &amp; more! https://t.co/AEaryWD0Vk https://t.co/uv6yy0bf9L
# (Fri Nov 20 02:31:40 +0000 2015) RT @lipmanb: $221.83 Million raised today by 29 startups. Data from @Crunchbase. - #VentureCapital #VC #Startup #entreprenuership https://t
# (Fri Nov 20 01:56:20 +0000 2015) @julien @Genius has raised 56.9m!
# (Thu Nov 19 18:42:30 +0000 2015) @danielppratt Hey Dan, page has been fixed!
# (Thu Nov 19 18:34:13 +0000 2015) @toddsaunders Hey Todd, the page has been edited. Thanks!
# (Thu Nov 19 17:24:10 +0000 2015) RT @hunterwalk: Square's initial funding roster via @crunchbase https://t.co/Lze5BXeJcY
# (Thu Nov 19 17:00:05 +0000 2015) #Accelerators! Did you know you can create Demo Day events? Promote your batch of companies! https://t.co/rqwL0TC6nm https://t.co/4pij0a5ET7
# (Thu Nov 19 16:57:15 +0000 2015) Today's #CBDaily: $1.2B in 302 rounds added &amp; more! https://t.co/AEaryWD0Vk https://t.co/xEIEwuOxqB
# (Thu Nov 19 15:47:23 +0000 2015) RT @StartUscc: The #European #tech and #startup #ecosystem is on the rise!
#
# https://t.co/R02OP7tVhe
#
# #eu #whatsnext4eutech https://t.co/XXg
# (Thu Nov 19 07:54:55 +0000 2015) Thanks Chris!  @UhrigX #mustuse https://t.co/I3og4xyev1
# (Wed Nov 18 20:23:05 +0000 2015) @Pippa050 Searched for your email but we haven't received it. Please email us at feedback@crunchbase.com, we'd love to help!
# (Wed Nov 18 17:18:40 +0000 2015) Today's #CBDaily: $1.4B in 330 rounds added &amp; more! https://t.co/AEaryWD0Vk https://t.co/KrVVnGYzu3
# (Wed Nov 18 17:00:08 +0000 2015) Hey #Accelerators! Check out the perks of our Venture Program - Join the other 2k+ members! https://t.co/b2tzTiUg1I https://t.co/WiQvEsJM7O
# (Wed Nov 18 07:35:55 +0000 2015) @Pippa050 Hey Pippa, can you please email us with details. Happy to help! feedback@crunchbase.com
# (Wed Nov 18 07:34:13 +0000 2015) @pasinduu Hey Pasindu! Send us an email with details and we'll take a look. Thanks! feedback@crunchbase.com
# (Wed Nov 18 07:32:28 +0000 2015) RT @wesleyyuhn1: The 20 Highest Paying #Startup #Unicorns @wesleyyuhn1 @CrunchBase https://t.co/UGUt639UPP #Entrepreneur #FinTech https://t
# (Wed Nov 18 07:31:45 +0000 2015) RT @lipmanb: $503.93 Million raised today by startups. Data from @Crunchbase. - #VentureCapital #VC #Startup #entreprenuership https://t.co
# (Wed Nov 18 07:31:23 +0000 2015) RT @eswarpr: Hey @crunchbase, here's how we (@tastefulapp) are helping #Paleo eaters discover #realfood! https://t.co/zuWYj6Pj0N #Startup
# (Tue Nov 17 19:06:45 +0000 2015) Thanks! We love to hear from CrunchBase users. #Unicorn obsessed? Check out our leaderboards https://t.co/irpqFRMJV2 https://t.co/8Cl80XRVi3
# (Tue Nov 17 17:12:22 +0000 2015) Today's #CBDaily: $1.4B in 199 rounds added &amp; more! https://t.co/AEaryWD0Vk https://t.co/HJymTalYks
# (Tue Nov 17 17:00:16 +0000 2015) Starting next month, we'll be featuring demo days &amp; application deadlines in #CBDaily. Add your info to be featured! https://t.co/HRbUC6imus
# (Tue Nov 17 15:49:56 +0000 2015) RT @33entrepreneurs: Dear friends, have a look @crunchbase and register to @33entrepreneurs 's #DemoDay : https://t.co/8Z9RRkkYCp
# (Tue Nov 17 04:35:38 +0000 2015) RT @lipmanb: $65.2 Million raised today by startups. Data from @Crunchbase. -#VentureCapital #VC #Startup https://t.co/gf1yanCHtg
# (Mon Nov 16 16:24:24 +0000 2015) Today's #CBDaily: $415M in 164 rounds added &amp; more! https://t.co/MNUxay2bsB https://t.co/rE68R1ifiu
# (Sun Nov 15 20:13:45 +0000 2015) RT @MsTechGroup: Among the top five women there, we're following @HillaryClinton and @ladygaga on @CrunchBase https://t.co/rssUp46sZf
# (Fri Nov 13 22:41:20 +0000 2015) RT @michaelambjorn: Key slide for me in 'The State of European Tech': a strong base of mentors https://t.co/rCUjfSRyhI #SLUSH15 #whatsnext4
# (Fri Nov 13 20:30:57 +0000 2015) @aidandcunniffe @maxlynch Hey Max, the page has been updated. Thanks!
# (Fri Nov 13 20:29:17 +0000 2015) @TomWillis608 @listrophy @maxlynch thanks for letting us know! It should be updated.
# (Fri Nov 13 16:57:50 +0000 2015) RT @boydcohen: I am a fan of using screenshots from @crunchbase in my entrepreneurship classes and when discussing business models w/ start
# (Fri Nov 13 16:49:36 +0000 2015) RT @sparkcapital: A startup that helps ppl find &amp; book the best activities in the world has raised $50M https://t.co/T6JkDJ8GqV @GetYourGui
# (Fri Nov 13 15:59:37 +0000 2015) Today's #CBDaily: $413M in 126 rounds added &amp; more! https://t.co/MNUxay2bsB https://t.co/WVVvU3Lkvi
# (Fri Nov 13 05:34:29 +0000 2015) RT @hannaontheroad: Super interesting study about the state of mind of EU tech &amp; entrepreneurs by @atomico https://t.co/En1FSHRqk0 #whatsne
# (Fri Nov 13 03:58:19 +0000 2015) RT @LudwigDumont: The @crunchbase #unicorn leaderboard https://t.co/oPBRTo2Hm5  #BeTech https://t.co/9E3uu98wrR
# (Fri Nov 13 03:57:22 +0000 2015) @lindseycwilder
# (Thu Nov 12 23:49:37 +0000 2015) Congrats @msquinn on your new role! Check out Spark Capital's profile. #WomenInVenture https://t.co/7WSPKPNflZ https://t.co/QMvz5Q8aLJ
# (Thu Nov 12 17:49:54 +0000 2015) Today's #CBDaily: $1.3B in 150 rounds added &amp; more! https://t.co/AEaryWD0Vk https://t.co/8K7SZUYKqZ
# (Thu Nov 12 06:11:04 +0000 2015) RT @Forbes: Europe's startup economy is in the best shape it's ever been. But it still needs work: https://t.co/61kk6SoE6D https://t.co/ktn
# (Thu Nov 12 05:45:27 +0000 2015) RT @danprimack: ICYMI: Snapchat isn't the only startup in Fidelity's crosshairs. Look out Blue Bottle, Dataminr, Zenefits &amp; more https://t.
# (Thu Nov 12 04:06:02 +0000 2015) RT @atomico: 8) But not mission accomplished: we must increase the number of women in tech at all levels #whatsnext4eutech
# (Thu Nov 12 04:02:46 +0000 2015) RT @atomico: 7) But not mission accomplished: we must improve the interconnectivity between tech hubs #whatsnext4eutech
# (Thu Nov 12 04:00:39 +0000 2015) RT @twehmeier: The State of European Tech: Achievement unlocked, but not mission accomplished #whatsnext4eutech @atomico @SlushHQ  https://
# (Thu Nov 12 01:10:18 +0000 2015) RT @runido: Heard at Slush 2015 "startups in Europe are on track to raise $10B in investments this year alone" https://t.co/BUELzIOq1F via
# (Wed Nov 11 17:26:49 +0000 2015) Today's #CBDaily: $3.0B in 222 rounds added &amp; more! https://t.co/AEaryWlq3M https://t.co/a9gIhBZZ1F
# (Wed Nov 11 06:12:13 +0000 2015) RT @maiab: When Startups Don't (re-)Raise: https://t.co/nt3lmfoBUY
# (Wed Nov 11 05:07:35 +0000 2015) RT @guy_levin: Great report on the state of European tech from @atomico #whatsnext4eutech https://t.co/nVBHTlGtLw
# (Wed Nov 11 04:08:37 +0000 2015) RT @AShady: Doing some network analytics on co-investments by VCs, and guess who tops the list? @500Startups @davemcclure https://t.co/E2qL
# (Wed Nov 11 02:21:12 +0000 2015) RT @wef: Will this be the key to economic success in 2050? https://t.co/ABAK579r9p #innovation #economics https://t.co/adPtANC3jF
# (Tue Nov 10 23:33:54 +0000 2015) RT @atomico: Thank you to our data partners @stackoverflow @crunchbase @meetup @glassdoor and our survey respondents
# (Tue Nov 10 23:33:20 +0000 2015) We're excited to partner with @atomico on the state of European tech. Check out the full report! #whatsnext4eutech  https://t.co/uSTemRhFg8
# (Tue Nov 10 22:54:33 +0000 2015) RT @StephenNellis: What happens when startups don't raise $$$ for a while? Turnarounds, fire sales &amp; funding pitches, w/ @crunchbase https:
# (Tue Nov 10 21:24:49 +0000 2015) RT @bryce: "Companies that have raised in the past tend to do so again to take advantage of higher valuations" https://t.co/xyTw55E7yq
# (Tue Nov 10 20:26:42 +0000 2015) RT @VCRebecca: .@BNarasin comments on 'sizzle' vs 'steak' in the latest CrunchBase Daily https://t.co/DyLbdo1CDM via @crunchbase #startups
# (Tue Nov 10 20:11:03 +0000 2015) RT @amir: These 62 startups didn't fundraise in last 2+ yrs, one of the easiest-money eras ever. https://t.co/hpEPHsFXLG https://t.co/5hvpb
# (Tue Nov 10 18:59:21 +0000 2015) RT @CanvasVC: .@BNarasin comments on 'sizzle' vs 'steak' in the latest CrunchBase Daily https://t.co/EqDplatESE via @crunchbase #startups
# (Tue Nov 10 18:40:16 +0000 2015) RT @DtNever: Super cool chart by CrunchBase and The Information "When Startups don't raise" #startup #seed #angelinvesting  https://t.co/JN
# (Tue Nov 10 18:17:38 +0000 2015) We've teamed up w/ @theinformation! Take a look at our analysis, When Startups Don't Raise: https://t.co/EAlxjA9Qox https://t.co/C9VFQhLCQg
# (Tue Nov 10 17:51:18 +0000 2015) RT @Jessicalessin: Trying some new stuff with @crunchbase. Woohoo! Story here: https://t.co/Ty9wyazglP https://t.co/VMhL2B57yT
# (Tue Nov 10 17:17:29 +0000 2015) Today's #CBDaily: $3.9B in 257 rounds added &amp; more! https://t.co/DnYOsSiEKW https://t.co/MtASqBJ4Bj
# (Mon Nov 09 23:45:14 +0000 2015) @Uptake sure! please send us both profile URLs and which one you'd like to merge. Thanks! feedback@crunchbase.com
# (Mon Nov 09 19:23:38 +0000 2015) @BNarasin
# (Mon Nov 09 19:23:07 +0000 2015) RT @BNarasin: My most recent story made it into the Crunchbase e-mail :-) 'Check out CrunchBase Daily' https://t.co/FrCGjeFe9X via @crunchb
# (Mon Nov 09 19:22:19 +0000 2015) RT @ClevelandBob: The new, more dashboard-like UI of @Crunchbase is a huge upgrade. Highly recommended. https://t.co/UkclAlWDkp
# (Mon Nov 09 19:22:15 +0000 2015) @ClevelandBob thanks Bob! We value your feedback! You can also send us a note with any input.  feedback@crunchbase.com
# (Mon Nov 09 16:06:52 +0000 2015) Today's #CBDaily: $5.4B in 490 rounds added &amp; more! https://t.co/MNUxay2bsB https://t.co/acnSOhipEG
# (Sun Nov 08 22:00:46 +0000 2015) RT @simonmurphy10: A useful source of data on the ever increasing unicorn list - The @CrunchBase UnicornLeaderboard https://t.co/Odvqee1gU
# (Sun Nov 08 03:02:02 +0000 2015) What's your pitch? It's a packed house at startup competition &amp; judges are ready! #WeArePTE https://t.co/y4oVZVGjXo
# (Sun Nov 08 02:09:35 +0000 2015) .@ParisaCNN "I have a front row seat in history, and I consider CNN the original social media." #WeArePTE https://t.co/VsziqcUNyh
# (Sun Nov 08 01:35:36 +0000 2015) .@apartovi "to ensure success, follow &amp; surround yourself with good people." @codeorg #WeArePTE
# (Sun Nov 08 01:24:43 +0000 2015) Investor panel: "Think about what your company does, and what's the smartest money for your company." @neildugal @500Startups #WeArePTE
# (Sun Nov 08 01:00:34 +0000 2015) .@apartovi "Education is the biggest form of impact to enable and empower." #WeArePTE https://t.co/9XzBm09jhf https://t.co/kghXx9MK4D
# (Sat Nov 07 23:07:31 +0000 2015) "Success in Silicon Valley is a result of many, many failures. It's learning." Farzad Naimi @ Naimi Group #WeArePTE https://t.co/Tp8jI6AATP
# (Sat Nov 07 22:20:42 +0000 2015) "You need to sell your vision, not your company," @ksub15 #WeArePTE
# (Sat Nov 07 21:39:20 +0000 2015) It's Pebble time at #WeArePTE! @ericmigi "Get your product right and simplify your message," https://t.co/r6GbXcZ0fg https://t.co/OSY5p9kUvE
# (Sat Nov 07 17:43:38 +0000 2015) RT @TechCrunch: Emergence Capital Investor Wants To Show Off Entrepreneurs' Super Powers With Graphic Novel https://t.co/pXE379bAkR by @Cat
# (Fri Nov 06 23:27:44 +0000 2015) @CherFeldman @salesforce Hey Cheryl, please send us an email the data team will take a look. Thanks! data@crunchbase.com
# (Fri Nov 06 18:21:31 +0000 2015) RT @KateDMitchell: New @StanfordBiz study shows impact of venture capital. Of 1,339 IPOs since 1974, 42% were venture-backed https://t.co/W
# (Fri Nov 06 17:21:07 +0000 2015) Today's #CBDaily: $2.8B in 244 rounds added &amp; more! https://t.co/AEaryWlq3M https://t.co/J7zXNAOtHL
# (Fri Nov 06 04:15:37 +0000 2015) @snielsen42 it would be best, thanks!
# (Fri Nov 06 03:28:05 +0000 2015) @snielsen42 please email us with your request thanks! data@crunchbase.com
# (Thu Nov 05 22:31:39 +0000 2015) RT @ProductHunt:  @CrunchBase Unicorn Leaderboard: A Leaderboard of private companies w/ &gt; $1BN Valuations https://t.co/TcfatJGduJ https:
# (Thu Nov 05 16:59:36 +0000 2015) Today's #CBDaily: $2.6B in 199 rounds added &amp; more! https://t.co/Kf7bEMjo71 https://t.co/QyP7rsTuDo
# (Thu Nov 05 02:09:17 +0000 2015) @motoceo Hey Aaron! The Crunched twitter handle is incorrect, it might be moved to ClearSlide.
# (Wed Nov 04 19:18:10 +0000 2015) @stephansonic thanks for your tweet!
# (Wed Nov 04 19:16:18 +0000 2015) @AndeLyons thanks for your tweet!
# (Wed Nov 04 17:20:46 +0000 2015) Today's #CBDaily: $2.2B in 219 rounds added &amp; more! https://t.co/AEaryWD0Vk https://t.co/R1K2gVVeax
# (Wed Nov 04 15:21:46 +0000 2015) @ProductHunt @Nivo0o0 Thanks for the feature!
# (Wed Nov 04 00:39:26 +0000 2015) Congrats @wquist! View all of @slow's 136 investments on CrunchBase: https://t.co/np3wlj6GS0 https://t.co/idgbcURKSB
# (Tue Nov 03 21:06:55 +0000 2015) Thanks for including CrunchBase data @nvca! Advancing Women in the Entrepreneurial Ecosystem https://t.co/cWJPphpk5L https://t.co/2FnL3o6ElY
# (Tue Nov 03 20:51:30 +0000 2015) @jstraus thanks for the mention!
# (Tue Nov 03 18:26:42 +0000 2015) Are you an event organizer? Feature your upcoming tech events on CrunchBase, at no cost! https://t.co/rYnTv2EoMU https://t.co/BgKn6ahqpc
# (Tue Nov 03 17:27:58 +0000 2015) Today's #CBDaily: $2.7B in 234 rounds added &amp; more! https://t.co/AEaryWD0Vk https://t.co/gobQrRnGSj
# (Tue Nov 03 16:15:13 +0000 2015) @crandl @NathanKinch join the Venture Program, membership is free! https://t.co/b2tzTiUg1I
# (Tue Nov 03 05:33:37 +0000 2015) RT @benmartinezJ: Six Tips: How to Run an Effective Engineering Organization - https://t.co/u2NWnpAKZ1 #organization #development
# (Tue Nov 03 04:50:06 +0000 2015) RT @AndreaMahoneyWF: Infographic: Female Startup Founders On An Upward Trend - Nearly doubled in 2014 https://t.co/Eo3ThReXJt @crunchbase
# (Tue Nov 03 00:55:34 +0000 2015) Kudos @inventureVC! Look at the great partner data. Thanks for being in the Venture Program! https://t.co/b2tzTiUg1I https://t.co/EFgxLBeDiG
# (Mon Nov 02 22:52:41 +0000 2015) Presidential Proclamation: #NationalEntrepreneurshipMonth via @WhiteHouse https://t.co/04kcStZY4X
# (Mon Nov 02 22:00:13 +0000 2015) RT @lipmanb: $51.962 Million raised today by startups. Data from @crunchbase. -#VentureCapital #VC #Startup https://t.co/tHo3lM5HVu
# (Mon Nov 02 21:56:19 +0000 2015) @leosaraceni Hey Leonardo! Please send us an email with the duplicate URLs you'd like to merge. Thanks! feedback@crunchbase.com
# (Mon Nov 02 18:17:33 +0000 2015) Today's #CBDaily: $3.1B in 307 rounds added &amp; more! https://t.co/lghtlFVJkB https://t.co/ZtvI5rs2Mp
# (Mon Nov 02 16:53:21 +0000 2015) @lipmanb can you please send us an email w/ details to retrieve your api key? Thanks! data@crunchbase.com
# (Sat Oct 31 19:33:41 +0000 2015) @lipmanb Hey Brandon! The data team has been notified.
# (Fri Oct 30 22:02:29 +0000 2015) Check out all #batch14 startups pitching! Including apptuto featured in today's #CBDaily:  https://t.co/IUxDozFr37 https://t.co/4w0VDOzCxe
# (Fri Oct 30 21:27:25 +0000 2015) It's a packed house @500Startups! Check out #batch14 startups on CrunchBase: https://t.co/IUxDozFr37 https://t.co/rQczHrm0rg
# (Fri Oct 30 19:40:21 +0000 2015) @drewbeechler thanks for letting us know! Can you please send us your registered email &amp; we'll remove you manually. feedback@crunchbase.com
# (Fri Oct 30 19:35:45 +0000 2015) Unicorn obsessed? Visit our leaderboards &amp; see which are current, emerging, and exited! https://t.co/irpqFRMJV2 https://t.co/YMEJ6lGWrl
# (Fri Oct 30 19:15:51 +0000 2015) @marcelweiss thanks for letting us know! It's been updated.
# (Fri Oct 30 19:07:05 +0000 2015) We've teamed up with @atomico &amp; @SlushHQ to assess the state of European venture investing: https://t.co/kU7IuosrdY https://t.co/JEeeBCsEGK
# (Fri Oct 30 16:47:38 +0000 2015) Today's #CBDaily: $518M in 190 rounds added &amp; more! https://t.co/E4kdWDCVBX https://t.co/ISQUwGPrgv
# (Thu Oct 29 20:49:21 +0000 2015) @B3ingThatGuy Hey Alex, the team is working to resolve it. It should be back up, thanks for your patience!
# (Thu Oct 29 20:39:53 +0000 2015) @mickithoughts Hey Micki, the team is working hard to resolve it. Thanks for your patience!
# (Thu Oct 29 16:05:10 +0000 2015) Today's #CBDaily: $707M in 166 rounds added &amp; more! https://t.co/AEaryWD0Vk https://t.co/9lEpxkeVML
# (Thu Oct 29 15:58:55 +0000 2015) @BaileyKo please email us with details and we'll take a look. Thanks! feedback@crunchbase.com
# (Thu Oct 29 08:46:14 +0000 2015) @jonmccull we've launched a new UI w/ new features, upgrade account etc. Any questions feel free to email us. We'll take a look thanks!
# (Thu Oct 29 08:36:23 +0000 2015) @jonmccull please send us your registered email &amp; we'll remove you manually. Thanks! feedback@crunchbase.com
# (Thu Oct 29 03:54:36 +0000 2015) @TerenaBell @andrewackerman
# (Thu Oct 29 03:51:41 +0000 2015) RT @TerenaBell: @andrewackerman Founders' alphabet book: C is for CrunchBase.
# (Thu Oct 29 03:37:48 +0000 2015) @liampmccabe thanks! Hey @jamesm, also check out CrunchBase Daily!
# (Thu Oct 29 02:18:30 +0000 2015) @rickykwok_ awesome! Noted!
# (Thu Oct 29 02:16:39 +0000 2015) @quire_io please send us an email w/ specifics. We'll take a look. Thanks! feedback@crunchbase.com
# (Thu Oct 29 02:14:06 +0000 2015) @BaileyKo Hey Bailey! Were you able to resolve? Send us an email w/specifics thanks. feedback@crunchbase.com
# (Wed Oct 28 23:51:29 +0000 2015) @pavelcurda great! Feel free to reach out to @geneteare directly.
# (Wed Oct 28 17:36:53 +0000 2015) @pavelcurda @davemcclure Hey Pavel, have you seen our female founder series? Happy to put you in touch w/ data team. https://t.co/uK1doFuksu
# (Wed Oct 28 17:27:31 +0000 2015) @Shashikamanoj Hey Shashika, you can edit your profile page by logging in &amp; select "Update" on each section. Thanks!
# (Wed Oct 28 17:25:41 +0000 2015) RT @James_Astor: How did I just find out about this!? Gold: "The @CrunchBase UnicornLeaderboard" https://t.co/2j5WnbrN3s via @techcrunch
# (Wed Oct 28 17:25:14 +0000 2015) @James_Astor thanks James! Have you signed up for our CrunchBase Daily email? You can keep up with the latest!
# (Wed Oct 28 15:13:35 +0000 2015) Today's #CBDaily: $2.6B in 142 rounds added &amp; more! https://t.co/PkOQAMc9RA https://t.co/WE4J4wwJvN
# (Tue Oct 27 21:44:41 +0000 2015) @rickykwok_ Hey Ricky, can you send us an email w/ specifics of what you're trying to update? Thanks! feedback@crunchbase.com
# (Tue Oct 27 21:42:48 +0000 2015) RT @shivagg: Great infographic via @crunchbase shows info on female startup founders &amp; they R on a upward trend @CrowdFundDiva
# https://t.c
# (Tue Oct 27 21:40:30 +0000 2015) @pronouncedJerry thanks for letting us know! please email us your registered email and we'll remove you manually. feedback@crunchbase.com
# (Tue Oct 27 16:31:27 +0000 2015) Today's #CBDaily: $2.3B in 131 rounds added &amp; more! https://t.co/Ai0cdkjlUS https://t.co/ftyxUcluIp
# (Tue Oct 27 16:22:35 +0000 2015) @NameRobotEN can you try again w/ a new email or send us your registered email &amp; we'll remove you manually. Thanks! feedback@crunchbase.com
# (Tue Oct 27 05:48:08 +0000 2015) @RichardGinsberg thanks for letting us know! Can you please provide specifics via email? Browser, device etc.
# (Tue Oct 27 01:23:02 +0000 2015) @jasnoorgill Hey Jasnoor, thanks for letting us know! Can you please try again?
# (Tue Oct 27 01:10:33 +0000 2015) @NameRobotEN Hey, thanks for letting us know! What was the date on the CB Alert email you're referring to?
# (Tue Oct 27 01:02:46 +0000 2015) @RichardGinsberg Hey Richard! Was it something specific? You can email us at feedback@crunchbase.com. Thanks!
# (Tue Oct 27 01:01:22 +0000 2015) @ryancharleston Hey Ryan, we've removed you from the list manually. Can you let us know which email you received? feedback@crunchbase.com
# (Tue Oct 27 00:58:43 +0000 2015) @Nikskinik Hey Nikki! Please email us w/ your existing registered email &amp; the new one you want. Thanks! feedback@crunchbase.com
# (Tue Oct 27 00:54:52 +0000 2015) @SimilarWeb @iammatthewdbell it should be up now! https://t.co/37agkd6m1W
# (Tue Oct 27 00:51:11 +0000 2015) @SimilarWeb Hey, we'll take a look. There might have been duplicate profiles. Thanks!
# (Mon Oct 26 16:02:05 +0000 2015) Today's #CBDaily: $1B in 168 rounds added &amp; more! https://t.co/eJs6rCCWag https://t.co/0ht6ZivKFw
# (Sun Oct 25 18:37:52 +0000 2015) @ehn Hey Andreas, thanks for letting us know! Shared it with the team, we'll take a look.
# (Sun Oct 25 00:08:22 +0000 2015) @k_morrissey @eastdakota Hey guys! If you'd like to edit the information, please select "Update" on the section. Thanks!
# (Sat Oct 24 17:29:39 +0000 2015) "VC-backed companies include some of the most innovative companies in the world." via https://t.co/mFABjZenQW https://t.co/SITuI4jKuE
# (Fri Oct 23 22:46:14 +0000 2015) @JulianNorton also please specify which email newsletter you're referring to. Thanks!
# (Fri Oct 23 22:20:38 +0000 2015) @juancarlosfarah Hey Juan! Thanks for letting us know. We'll take a look.
# (Fri Oct 23 22:14:19 +0000 2015) @JulianNorton Hey Julian! Thanks for sharing. Plz email us w/ the registered email you'd like to remove. feedback@crunchbase.com
# (Fri Oct 23 15:24:24 +0000 2015) Today's #CBDaily: $650M in 145 rounds added &amp; more! https://t.co/Yjupsvjhx8 https://t.co/hSC5iRc40y
# (Fri Oct 23 14:11:26 +0000 2015) RT @ameliabeamer: Great infographic via @crunchbase shows info on female startup founders &amp; shows they're on an upward trend #mno6172 https
# (Fri Oct 23 04:56:16 +0000 2015) .@HaD_XIII great feature! 3 Key differences between European vs US startups via @StartupGrind  https://t.co/YYplcC8XvJ
# (Fri Oct 23 02:55:43 +0000 2015) @josh_nussbaum Hey Josh! We love to hear user feedback. Can you email us re: those follow recos? Thanks! feedback@crunchbase.com
# (Thu Oct 22 23:54:19 +0000 2015) @Rachelk234 Hey Rachel! Can you please email us w/ details including iOS version &amp; which browser. Thanks! feedback@crunchbase.com.com
# (Thu Oct 22 23:51:13 +0000 2015) @DjukicVuk here's the data to back it up! https://t.co/j9awxLnDM5
# (Thu Oct 22 21:05:17 +0000 2015) We're excited to team up w/@LtStartup in representing the Lithuanian Startup community! https://t.co/8OVwr7sde9
# (Thu Oct 22 20:14:45 +0000 2015) #TBT to #WHDemoDay! @BarackObama:"The next Steve Jobs might be named Stephanie or Esteban." https://t.co/b1Px4D9u4e https://t.co/NKry3tDjff
# (Thu Oct 22 17:09:15 +0000 2015) Today's #CBDaily: $680M in 118 rounds added. @numerify @moneyforward @PeriscopeData &amp; more! https://t.co/swzgV7ACOt https://t.co/apjwquwHHe
# (Thu Oct 22 05:19:16 +0000 2015) Congrats @GoogleVentures! Leading the $81M Series C in Collective Health: https://t.co/8WRF5g1mtf https://t.co/bT97UteRgQ
# (Thu Oct 22 02:42:51 +0000 2015) Lead Investor &amp; Partner data is now live on CrunchBase. Join our venture program, it's free! https://t.co/b2tzTiUg1I https://t.co/VT3wjjdaZ5
# (Wed Oct 21 22:27:01 +0000 2015) Hey @transitapp! fyi. you can add them to your profile page under "add board members &amp; advisors" section, thanks! https://t.co/fC8wLV7uUk
# (Wed Oct 21 21:09:56 +0000 2015) @kubakostecki Hey Jakub! You can edit a profile page by selecting 'Update' on each section. Thanks!
# (Wed Oct 21 17:03:45 +0000 2015) Today's #CBDaily: $1.8B in 133 rounds added. @collectvhealth @honestbeesg @bownty &amp; more! https://t.co/qm8HZriIGf https://t.co/yKrcEIFtWc
# (Wed Oct 21 16:51:43 +0000 2015) @MattTutt1 Hey Matt! We'll take a look. Can you please email us the URL + sections you're trying to update? feedback@crunchbase.com
# (Tue Oct 20 23:05:52 +0000 2015) @elof Hey Justin, the team is aware and working to resolve it soon. Thanks for your patience!
# (Tue Oct 20 22:58:16 +0000 2015) Shoutout to @karlamartin4147! Congrats on the new board position at Challenged! https://t.co/rNrmPa95IK https://t.co/hPduRWMBPG
# (Tue Oct 20 22:09:40 +0000 2015) Hey CB users! If you're experiencing any delays using the site, our team is currently working hard to resolve it. Thanks for your patience!
# (Tue Oct 20 16:22:55 +0000 2015) @kylebragger Hey Kyle, can you please email us w/ your registered email address, we'll remove it manually. Thanks! feedback@crunchbase.com
# (Tue Oct 20 01:30:46 +0000 2015) @shalk9 Hey Shalini! You can edit a profile page by selecting 'Update' on the sections you'd like to update.
# (Tue Oct 20 01:28:54 +0000 2015) @shalk9 we can help! Please email us the URLs and we'll delete the duplicate profile. Thanks! feedback@crunchbase.com
# (Tue Oct 20 00:56:31 +0000 2015) Awesome partner data @episode1VC! p.s. VCs, you can also feature your partners. Learn how: https://t.co/b2tzTiUg1I https://t.co/k643jbAopA
# (Mon Oct 19 19:32:11 +0000 2015) @ginoarendsz Hey Gino! Can you please email us the logo you're trying to upload to the profile page? feedback@crunchbase.com
# (Mon Oct 19 16:27:38 +0000 2015) @ginoarendsz thanks for letting us know! It's been shared, the team is taking a look.
# (Mon Oct 19 16:05:33 +0000 2015) Today's #CBDaily: $2.6B in 352 rounds added. @CitrusPay @Cube26labs @wearetrouva &amp; more! http://t.co/oYk7oI0PZV http://t.co/PydIPswyKU
# (Mon Oct 19 03:01:59 +0000 2015) @dustinfarris Hey Dustin, thanks for letting us know! The data team is looking at your request and will reach out to you via email.
# (Mon Oct 19 01:06:22 +0000 2015) @dustinfarris please email data@crunchbase.com w/ details. We'll take a look thanks!
# (Mon Oct 19 01:03:08 +0000 2015) RT @jowyang: Crunchbase has shown a lot of improvements in data, layout, and new insights.
# (Sat Oct 17 06:56:50 +0000 2015) RT @twehmeier: Please add your voice to the many many entrepreneurs from all across Europe who have already had their say! @SlushHQ https:/
# (Sat Oct 17 03:05:02 +0000 2015) These four tech #unicorns could reshape their industries via @mhelft @forbes http://t.co/HsFEa8Ks6W
# (Fri Oct 16 21:10:19 +0000 2015) RT @ByGeekgirl: Female startup founders on an upward trend, according to @CrunchBase. http://t.co/0lrfoL46l9 #womenintech http://t.co/rhBiu
# (Fri Oct 16 18:56:58 +0000 2015) Who knew a short copy description in today's #CBDaily would trigger a phishing warning? No worries, we're on it! http://t.co/lHnRIVhsyu
# (Fri Oct 16 15:00:44 +0000 2015) Today's #CBDaily: $3.0B in 287 rounds added. @lyrahealth @quip @KlookTravel &amp; more! http://t.co/DTEqB4dyyZ http://t.co/qBzPsFjMle
# (Fri Oct 16 06:09:43 +0000 2015) RT @joelle_emerson: Want to measure how inclusive your tech co is? @prdgm and @CultureAmp are designing a survey to do just that! #GHC15 ht
# (Fri Oct 16 00:18:28 +0000 2015) Hey VCs &amp; Startups! Take the Slush 2015 Survey to help assess the state of #EuroTech! http://t.co/hPQt4YgEr7 http://t.co/xyYBlvz7gf
# (Thu Oct 15 21:52:53 +0000 2015) Now you can check out all deals led by @johnolilly, including his recent Series B in @quip! http://t.co/Mco68F7V6C http://t.co/fu1GKuHykT
# (Thu Oct 15 21:02:01 +0000 2015) @AChamarthy the team is currently working to resolve it. Can you please email us your registered email? Thanks! feedback@crunchbase.com
# (Thu Oct 15 19:06:15 +0000 2015) Excited to be @beGLOBALSF! Now judging Startup Battle: our own @kaufman_matt plus @patrickchung @timy0ung @TTCP_SF http://t.co/xzAazMSI7B
# (Thu Oct 15 17:33:44 +0000 2015) Today's #CBDaily: $3.8B in 304 rounds added. @OpenGovInc @NianticLabs @Kinnek &amp; more! http://t.co/6OT2VpsSHR
# (Thu Oct 15 15:14:39 +0000 2015) @PointForwardPro Hey Kris, can you please email us w/ the details &amp; which profile? We'll take a look thanks! feedback@crunchbase.com
# (Thu Oct 15 15:11:36 +0000 2015) RT @koreastartups: Meet Key Speakers at once @beGLOBALSF Oct.15! Ticket: http://t.co/jS6Qld7y3v
# @AngelList @crunchbase, @MayfieldFund http:
# (Thu Oct 15 05:27:33 +0000 2015) @WolfgangBremer thanks for letting us know! Please email us w/ the email registered &amp; we'll manually remove it. feedback@crunchbase.com

# %%
startuplist = [##"Uber",
##"Xiaomi",
##"Airbnb",
#"Palantir Technologies",
##"Snapchat",
##"Flipkart",
#"Didi Kuaidi",
##"SpaceX",
##"Pinterest",
##"Dropbox",
##"Lufax",
##"WeWork",
#"DJI Innovations",
##"Theranos",
##"Spotify",
##"Meituan",
#"Intarcia Therapeutics",
##"Stripe",
##"Olacabs",
##"Coupang",
##"Zenefits",
##"Cloudera",
####"Dianping",
#"Social Finance",
##"Tanium",
#"Credit Karma",
##"Atlassian",
##"Jawbone",
#"Delivery Hero",
#"Global Fashion Group",
##"Fanatics",
#"Legendary Entertainment",
##"Stemcentrx",
#"Ele.me",
##"VANCL",
##"DocuSign",
##"Moderna",
#"ContextLogic (dba. Wish)",
##"Hellofresh",
#"Slack Technologies",
##"slack",
#"Bloom Energy",
#"POWA Technologies",
##"Snapdeal",
##"Lyft",
##"Vice",# Media",
##"Mozido",
##"Adyen",
##"Houzz",
##"Klarna",
##"SurveyMonkey",
##"Evernote",
##"Avant",
##"NantHealth",
##"Nutanix",
#"One97 Communications",
##"Github",
#"Domo Technologies",
#"Trendy Group International",
##"Instacart",
#"Blue Apron",
#"Magic Leap",
#"Prosper Marketplace",
##"Zocdoc",
#"Oscar Health Insurance Co.",
#"The Honest Company",
##"MongoDB",
##"BlaBlaCar",
#"Insidesales.com",
#"Mu Sigma",
##"GuaHao",
##"MuleSoft",
##"Buzzfeed",
#"Jet.com",
##"ironSource",
#"Koudai Gouwu",
#"Jasper Technologies",
##"DraftKings",
##"Deem",
##"Thumbtack",
##"Lazada",
##"Medallia",
#"Ucar Group",
##"Appnexus",
#"Warby Parker",
#"Auto1 Group",
##"Infinidat",
##"Okta",
##"Sprinklr",
##"Automattic",
##"Twilio",
##"Uptake",
##"Udacity",
#"Proteus Digital Health",
##"Actifio",
##"TangoMe",
##"Nextdoor",
##"Docker",
#"Gilt Groupe",
##"Home24",
##"23andMe",
####"TransferWise",
##"Shazam",
#"Apus Group",
##"CloudFlare",
##"Eventbrite",
##"Lookout",
##"AppDynamics",
##"Farfetch",
####"SimpliVity",
##"Hootsuite",
##"Kabam",
#"Funding Circle",
##"Tujia",
##"Razer",
#"China Rapid Finance",
##"Fanli",
#"Zomato Media",
##"JustFab",
##"Qualtrics",
##"Mogujie",
##"Illumio",
##"GrabTaxi",
##"BeiBei",
##"Panshi",
#"Yello Mobile",
##"Pluralsight",
##"Quikr",
##"InMobi",
#"iwjw.com",
####"AVAST",# Software",
"MarkLogic",
#"Coupa Software",
"Fanduel",
#"Zeta Interactive",
"Zscaler",
"Vox",# Media",
#"Kik Interactive",
"Decolar",
"Carbon3D",
"Apttus",
"AppDirect",
"Kabbage",
"Datto",
###"TutorGroup"]

# %%
import tweepy #https://github.com/tweepy/tweepy
import csv

#Twitter API credentials
CONSUMER_KEY = 'LUDiw6UJwbcOpJxCUMwprQTjz'
CONSUMER_SECRET ='eRZxk3NObvhfdRPlqSZnjcAnilPCRkaV16616mI86Fzi6ENi35'
OAUTH_TOKEN = '1150071104-cBt0I6tLwweKg5LlMHRSN8sZS22lXsXPCGOpW4Z'
OAUTH_TOKEN_SECRET = 'aulODA2dhSCLgyiTLJ74adyPtJ2mShhhfWUx9FJkpJzXa'
consumer_key = CONSUMER_KEY
consumer_secret = CONSUMER_SECRET
access_key = OAUTH_TOKEN
access_secret = OAUTH_TOKEN_SECRET


def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method

    #authorize twitter, initialize tweepy
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth, retry_delay=61, retry_count=16, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

    #initialize a list to hold all the tweepy Tweets
    alltweets = []	

    #make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)
    #print new_tweets
    #raise Exception()
    #save most recent tweets
    alltweets.extend(new_tweets)

    #save the id of the oldest tweet less one
    if len(alltweets) > 1:
        oldest = alltweets[-1].id - 1
    else:
        oldest = None

    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
        print "getting tweets before %s" % (oldest)

        #all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = None
        #while new_tweets == None:
#            try:
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
 #           except:# RateLimitError:
  #              for i in xrange(0,3):
   #                 print "sleeping for 5 minutes to get around rate limit"
    #                sleep(61 * 5) #15 minute sleep try for wait limit
     #           pass
            #except TweepError:
             #   print "tweeperr"
              #  break
               # pass
            #else:
             #   print "wtf else"
        #save most recent tweets
        alltweets.extend(new_tweets)

        #update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1

#		break

        print "...%s tweets downloaded so far" % (len(alltweets))

    #transform the tweepy tweets into a 2D array that will populate the csv	
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8"), \
                 str(tweet.favorite_count), str(tweet.retweet_count), tweet.lang.encode("utf-8"),\
#                 tweet.quoted_status_id_str, \
                 tweet.in_reply_to_screen_name,tweet.in_reply_to_user_id_str,\
                 tweet.in_reply_to_status_id_str, \
                 tweet.place.country.encode("utf-8") if tweet.place else "", \
                 tweet.place.country_code.encode("utf-8") if tweet.place else "",\
                 tweet.place.full_name.encode("utf-8") if tweet.place else "",\
                 tweet.place.place_type.encode("utf-8") if tweet.place else "", \
                 str(tweet.coordinates['coordinates']).encode("utf-8") if tweet.coordinates else "", \
                 ] for tweet in alltweets]
#	print outtweets[2]
#	raise Exception()
    #write the csv	
    with open('%s_tweets.csv' % screen_name, 'wb') as f:
        writer = csv.writer(f)
        writer.writerow(["id","created_at","text","favorites","retweets","lang",\
                         #"quoting_status_id",\
                        "in_reply_to_user","in_reply_to_user_id","in_reply_to_status_id",\
                        "country","country_code","place_name","place_type","coordinates"])
        writer.writerows(outtweets)

    pass

for sta in startuplist:
    print sta
    get_all_tweets(sta)
#get_all_tweets('https://twitter.com/search-advanced')
# Out:
# MarkLogic
# getting tweets before 650695877351178239
# ...400 tweets downloaded so far
# getting tweets before 634387106865942527
# ...600 tweets downloaded so far
# getting tweets before 620249759714971647
# ...800 tweets downloaded so far
# getting tweets before 609440029987901439
# ...1000 tweets downloaded so far
# getting tweets before 598526619376975871
# ...1200 tweets downloaded so far
# getting tweets before 588404169179987967
# ...1400 tweets downloaded so far
# getting tweets before 581169230424502271
# ...1599 tweets downloaded so far
# getting tweets before 571742884904484863
# ...1798 tweets downloaded so far
# getting tweets before 564070580500975615
# ...1998 tweets downloaded so far
# getting tweets before 555081530758799359
# ...2198 tweets downloaded so far
# getting tweets before 544911086432952319
# ...2398 tweets downloaded so far
# getting tweets before 536187369838223360
# ...2598 tweets downloaded so far
# getting tweets before 529772626080587777
# ...2798 tweets downloaded so far
# getting tweets before 522473234550124545
# ...2998 tweets downloaded so far
# getting tweets before 514819047515361279
# ...3198 tweets downloaded so far
# getting tweets before 507241628419907583
# ...3205 tweets downloaded so far
# getting tweets before 506924577025302527
# ...3205 tweets downloaded so far
# Fanduel
# getting tweets before 667055317650268159
# ...400 tweets downloaded so far
# getting tweets before 662754368178036736
# ...600 tweets downloaded so far
# getting tweets before 659756355100676095
# ...800 tweets downloaded so far
# getting tweets before 655771870600560640
# ...1000 tweets downloaded so far
# getting tweets before 650070663991046143
# ...1200 tweets downloaded so far
# getting tweets before 647504903284367359
# ...1400 tweets downloaded so far
# getting tweets before 644626200921513983
# ...1600 tweets downloaded so far
# getting tweets before 643555688321445887
# ...1800 tweets downloaded so far
# getting tweets before 642357918030012415
# ...2000 tweets downloaded so far
# getting tweets before 635242425913470975
# ...2200 tweets downloaded so far
# getting tweets before 627159103790518272
# ...2400 tweets downloaded so far
# getting tweets before 616993355063554047
# ...2600 tweets downloaded so far
# getting tweets before 608659166278856704
# ...2800 tweets downloaded so far
# getting tweets before 601856962083614719
# ...3000 tweets downloaded so far
# getting tweets before 593450296849862655
# ...3200 tweets downloaded so far
# getting tweets before 585851866044563456
# ...3234 tweets downloaded so far
# getting tweets before 585081734364061695
# ...3234 tweets downloaded so far
# Zscaler
# getting tweets before 590193181590847487
# ...400 tweets downloaded so far
# getting tweets before 381159492203061247
# ...600 tweets downloaded so far
# getting tweets before 325369103323901951
# ...800 tweets downloaded so far
# getting tweets before 226456955366027263
# ...1000 tweets downloaded so far
# getting tweets before 9527238228
# ...1011 tweets downloaded so far
# getting tweets before 1283307076
# ...1011 tweets downloaded so far
# Vox
# getting tweets before 3332255119
# ...183 tweets downloaded so far
# Decolar
# getting tweets before 660189534920040451
# ...400 tweets downloaded so far
# getting tweets before 647510642992263167
# ...600 tweets downloaded so far
# getting tweets before 636912000774246400
# ...800 tweets downloaded so far
# getting tweets before 626369200425037823
# ...1000 tweets downloaded so far
# getting tweets before 618478075097956351
# ...1200 tweets downloaded so far
# getting tweets before 603915097694588929
# ...1400 tweets downloaded so far
# getting tweets before 585570062830018559
# ...1600 tweets downloaded so far
# getting tweets before 562324779265712127
# ...1800 tweets downloaded so far
# getting tweets before 539101589399937023
# ...2000 tweets downloaded so far
# getting tweets before 526762627306094591
# ...2200 tweets downloaded so far
# getting tweets before 511154476934516735
# ...2400 tweets downloaded so far
# getting tweets before 498848135578652671
# ...2600 tweets downloaded so far
# getting tweets before 479227635919507456
# ...2800 tweets downloaded so far
# getting tweets before 447802700240285695
# ...3000 tweets downloaded so far
# getting tweets before 423235980368564224
# ...3200 tweets downloaded so far
# getting tweets before 402957247502102527
# ...3206 tweets downloaded so far
# getting tweets before 402300611833892863
# ...3206 tweets downloaded so far
# Carbon3D
# getting tweets before 576858657800908799
# ...84 tweets downloaded so far
# Apttus
# getting tweets before 656768669356314623
# ...400 tweets downloaded so far
# getting tweets before 644593012274819075
# ...600 tweets downloaded so far
# getting tweets before 641596683332263935
# ...800 tweets downloaded so far
# getting tweets before 630863710496555007
# ...1000 tweets downloaded so far
# getting tweets before 619240921289232383
# ...1200 tweets downloaded so far
# getting tweets before 606890263664050176
# ...1400 tweets downloaded so far
# getting tweets before 590308658996588543
# ...1600 tweets downloaded so far
# getting tweets before 585824449481449471
# ...1800 tweets downloaded so far
# getting tweets before 570664058866634751
# ...2000 tweets downloaded so far
# getting tweets before 550214169447104511
# ...2200 tweets downloaded so far
# getting tweets before 530816598353772543
# ...2400 tweets downloaded so far
# getting tweets before 522512312616251392
# ...2600 tweets downloaded so far
# getting tweets before 521785639965298687
# ...2799 tweets downloaded so far
# getting tweets before 514132199646322687
# ...2999 tweets downloaded so far
# getting tweets before 505120776568045567
# ...3199 tweets downloaded so far
# getting tweets before 492347359074852863
# ...3243 tweets downloaded so far
# getting tweets before 490544111619813375
# ...3243 tweets downloaded so far
# AppDirect
# getting tweets before 651827662814474239
# ...400 tweets downloaded so far
# getting tweets before 603261583716933631
# ...600 tweets downloaded so far
# getting tweets before 542074296966066175
# ...800 tweets downloaded so far
# getting tweets before 481193135813697535
# ...1000 tweets downloaded so far
# getting tweets before 378456176650104831
# ...1199 tweets downloaded so far
# getting tweets before 271799062263656447
# ...1399 tweets downloaded so far
# getting tweets before 238316028180959232
# ...1599 tweets downloaded so far
# getting tweets before 204704372863664127
# ...1799 tweets downloaded so far
# getting tweets before 184437079630020609
# ...1998 tweets downloaded so far
# getting tweets before 165683515059470335
# ...2198 tweets downloaded so far
# getting tweets before 142671046187814913
# ...2398 tweets downloaded so far
# getting tweets before 131502025438527487
# ...2598 tweets downloaded so far
# getting tweets before 115938244427915264
# ...2798 tweets downloaded so far
# getting tweets before 102093152474759168
# ...2998 tweets downloaded so far
# getting tweets before 86917063305740288
# ...3198 tweets downloaded so far
# getting tweets before 65915508008030207
# ...3209 tweets downloaded so far
# getting tweets before 65181632033857535
# ...3209 tweets downloaded so far
# Kabbage
# getting tweets before 656297520671408127
# ...400 tweets downloaded so far
# getting tweets before 632316313793359874
# ...586 tweets downloaded so far
# getting tweets before 264195961
# ...586 tweets downloaded so far
# Datto
# getting tweets before 662318641522823167
# ...400 tweets downloaded so far
# getting tweets before 651779883568394239
# ...600 tweets downloaded so far
# getting tweets before 639517350627307519
# ...800 tweets downloaded so far
# getting tweets before 629336326991691775
# ...1000 tweets downloaded so far
# getting tweets before 619909239457345535
# ...1200 tweets downloaded so far
# getting tweets before 610514983290585088
# ...1400 tweets downloaded so far
# getting tweets before 595287536697778176
# ...1600 tweets downloaded so far
# getting tweets before 586267279182188545
# ...1800 tweets downloaded so far
# getting tweets before 578996673466228735
# ...2000 tweets downloaded so far
# getting tweets before 570949169139089407
# ...2200 tweets downloaded so far
# getting tweets before 565225511300124671
# ...2400 tweets downloaded so far
# getting tweets before 557582415766773759
# ...2599 tweets downloaded so far
# getting tweets before 547078663356035071
# ...2799 tweets downloaded so far
# getting tweets before 540198993897467903
# ...2999 tweets downloaded so far
# getting tweets before 532262728204046338
# ...3199 tweets downloaded so far
# getting tweets before 524641750636568575
# ...3238 tweets downloaded so far
# getting tweets before 522832451068903423
# ...3238 tweets downloaded so far
# TutorGroup
# getting tweets before None
# ...2 tweets downloaded so far
# getting tweets before 1720734362
# ...2 tweets downloaded so far

# %% [markdown]
# ## Example 2. Retrieving trends

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print world_trends
print
print us_trends
# Out:
# [{u'created_at': u'2015-11-24T20:44:53Z', u'trends': [{u'url': u'http://twitter.com/search?q=Roubaix', u'query': u'Roubaix', u'name': u'Roubaix', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23%D8%A8%D8%B1%D8%B4%D9%84%D9%88%D9%86%D9%87_%D8%B1%D9%88%D9%85%D8%A7', u'query': u'%23%D8%A8%D8%B1%D8%B4%D9%84%D9%88%D9%86%D9%87_%D8%B1%D9%88%D9%85%D8%A7', u'name': u'#\u0628\u0631\u0634\u0644\u0648\u0646\u0647_\u0631\u0648\u0645\u0627', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Roma', u'query': u'Roma', u'name': u'Roma', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23GRAMMYs', u'query': u'%23GRAMMYs', u'name': u'#GRAMMYs', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Bayern', u'query': u'Bayern', u'name': u'Bayern', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23NadaMejorQue', u'query': u'%23NadaMejorQue', u'name': u'#NadaMejorQue', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23%D8%B2%D8%AF_%D8%B1%D8%B5%D9%8A%D8%AF%D9%8311', u'query': u'%23%D8%B2%D8%AF_%D8%B1%D8%B5%D9%8A%D8%AF%D9%8311', u'name': u'#\u0632\u062f_\u0631\u0635\u064a\u062f\u064311', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23ThanksgivingWithBlackFamilies', u'query': u'%23ThanksgivingWithBlackFamilies', u'name': u'#ThanksgivingWithBlackFamilies', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=T%C3%BAnez', u'query': u'T%C3%BAnez', u'name': u'T\xfanez', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Susana+Malcorra%22', u'query': u'%22Susana+Malcorra%22', u'name': u'Susana Malcorra', u'promoted_content': None}], u'as_of': u'2015-11-24T20:49:44Z', u'locations': [{u'woeid': 1, u'name': u'Worldwide'}]}]
#
# [{u'created_at': u'2015-11-24T20:44:53Z', u'trends': [{u'url': u'http://twitter.com/search?q=%23ThanksgivingWithBlackFamilies', u'query': u'%23ThanksgivingWithBlackFamilies', u'name': u'#ThanksgivingWithBlackFamilies', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23RuinAnOldSaying', u'query': u'%23RuinAnOldSaying', u'name': u'#RuinAnOldSaying', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23UnHimno', u'query': u'%23UnHimno', u'name': u'#UnHimno', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Turkey', u'query': u'Turkey', u'name': u'Turkey', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%236YearsOfOneTime', u'query': u'%236YearsOfOneTime', u'name': u'#6YearsOfOneTime', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23iHeartShawnAndCamila', u'query': u'%23iHeartShawnAndCamila', u'name': u'#iHeartShawnAndCamila', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Johnny+Manziel%22', u'query': u'%22Johnny+Manziel%22', u'name': u'Johnny Manziel', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Roubaix', u'query': u'Roubaix', u'name': u'Roubaix', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Roma', u'query': u'Roma', u'name': u'Roma', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Lane+Johnson%22', u'query': u'%22Lane+Johnson%22', u'name': u'Lane Johnson', u'promoted_content': None}], u'as_of': u'2015-11-24T20:49:45Z', u'locations': [{u'woeid': 23424977, u'name': u'United States'}]}]

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print json.dumps(world_trends, indent=1)
print
print json.dumps(us_trends, indent=1)
# Out:
# [
#  {
#   "created_at": "2015-11-24T20:44:53Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=Roubaix",
#     "query": "Roubaix",
#     "name": "Roubaix",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A8%D8%B1%D8%B4%D9%84%D9%88%D9%86%D9%87_%D8%B1%D9%88%D9%85%D8%A7",
#     "query": "%23%D8%A8%D8%B1%D8%B4%D9%84%D9%88%D9%86%D9%87_%D8%B1%D9%88%D9%85%D8%A7",
#     "name": "#\u0628\u0631\u0634\u0644\u0648\u0646\u0647_\u0631\u0648\u0645\u0627",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Roma",
#     "query": "Roma",
#     "name": "Roma",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GRAMMYs",
#     "query": "%23GRAMMYs",
#     "name": "#GRAMMYs",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Bayern",
#     "query": "Bayern",
#     "name": "Bayern",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NadaMejorQue",
#     "query": "%23NadaMejorQue",
#     "name": "#NadaMejorQue",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%B2%D8%AF_%D8%B1%D8%B5%D9%8A%D8%AF%D9%8311",
#     "query": "%23%D8%B2%D8%AF_%D8%B1%D8%B5%D9%8A%D8%AF%D9%8311",
#     "name": "#\u0632\u062f_\u0631\u0635\u064a\u062f\u064311",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ThanksgivingWithBlackFamilies",
#     "query": "%23ThanksgivingWithBlackFamilies",
#     "name": "#ThanksgivingWithBlackFamilies",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=T%C3%BAnez",
#     "query": "T%C3%BAnez",
#     "name": "T\u00fanez",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Susana+Malcorra%22",
#     "query": "%22Susana+Malcorra%22",
#     "name": "Susana Malcorra",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2015-11-24T20:49:44Z",
#   "locations": [
#    {
#     "woeid": 1,
#     "name": "Worldwide"
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "created_at": "2015-11-24T20:44:53Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23ThanksgivingWithBlackFamilies",
#     "query": "%23ThanksgivingWithBlackFamilies",
#     "name": "#ThanksgivingWithBlackFamilies",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23RuinAnOldSaying",
#     "query": "%23RuinAnOldSaying",
#     "name": "#RuinAnOldSaying",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23UnHimno",
#     "query": "%23UnHimno",
#     "name": "#UnHimno",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Turkey",
#     "query": "Turkey",
#     "name": "Turkey",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%236YearsOfOneTime",
#     "query": "%236YearsOfOneTime",
#     "name": "#6YearsOfOneTime",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23iHeartShawnAndCamila",
#     "query": "%23iHeartShawnAndCamila",
#     "name": "#iHeartShawnAndCamila",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Johnny+Manziel%22",
#     "query": "%22Johnny+Manziel%22",
#     "name": "Johnny Manziel",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Roubaix",
#     "query": "Roubaix",
#     "name": "Roubaix",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Roma",
#     "query": "Roma",
#     "name": "Roma",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Lane+Johnson%22",
#     "query": "%22Lane+Johnson%22",
#     "name": "Lane Johnson",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2015-11-24T20:49:45Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print common_trends
# Out:
# set([u'Roubaix', u'#ThanksgivingWithBlackFamilies', u'Roma'])

# %% [markdown]
# ## Example 5. Collecting search results

# %%
# Import unquote to prevent url encoding errors in next_results
from urllib import unquote

# XXX: Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

#q = '#MentionSomeoneImportantForYou' 
q = '#marinecoin OR #startcoin OR #coinbase OR #bitstamp OR #bitfinex OR #altcoins OR #bitcoin OR #bitcoins OR #btc OR #dogecoin OR #crypto OR #cryptocurrency OR #blockchain' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print "Length of statuses", len(statuses)
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError, e: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in unquote(next_results[1:]).split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print json.dumps(statuses[0], indent=1)
# Out:
# Length of statuses 100
# Length of statuses 200
# Length of statuses 300
# Length of statuses 400
# Length of statuses 500
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "RT @LYNDONJJSTOKES: How safe is your water? FREE Audit here from Macol Consulting  https://t.co/vrKCUEEKF8  #bromsgrovehour #crypto https:/\u2026",
#  "is_quote_status": false,
#  "in_reply_to_status_id": null,
#  "id": 669258955160465408,
#  "favorite_count": 0,
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "retweeted": false,
#  "coordinates": null,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 2359987412,
#     "indices": [
#      3,
#      18
#     ],
#     "id_str": "2359987412",
#     "screen_name": "LYNDONJJSTOKES",
#     "name": "TheBestof Bromsgrove"
#    }
#   ],
#   "hashtags": [
#    {
#     "indices": [
#      108,
#      123
#     ],
#     "text": "bromsgrovehour"
#    },
#    {
#     "indices": [
#      124,
#      131
#     ],
#     "text": "crypto"
#    }
#   ],
#   "urls": [
#    {
#     "url": "https://t.co/vrKCUEEKF8",
#     "indices": [
#      83,
#      106
#     ],
#     "expanded_url": "http://bit.ly/1OquB2c",
#     "display_url": "bit.ly/1OquB2c"
#    }
#   ],
#   "media": [
#    {
#     "source_user_id": 2359987412,
#     "source_status_id_str": "669255922674454529",
#     "expanded_url": "http://twitter.com/LYNDONJJSTOKES/status/669255922674454529/photo/1",
#     "display_url": "pic.twitter.com/Jrjm6NMlNt",
#     "url": "https://t.co/Jrjm6NMlNt",
#     "media_url_https": "https://pbs.twimg.com/media/CUmstzrWsAAvl-a.jpg",
#     "source_user_id_str": "2359987412",
#     "source_status_id": 669255922674454529,
#     "id_str": "669255922607370240",
#     "sizes": {
#      "large": {
#       "h": 157,
#       "resize": "fit",
#       "w": 266
#      },
#      "small": {
#       "h": 157,
#       "resize": "fit",
#       "w": 266
#      },
#      "medium": {
#       "h": 157,
#       "resize": "fit",
#       "w": 266
#      },
#      "thumb": {
#       "h": 150,
#       "resize": "crop",
#       "w": 150
#      }
#     },
#     "indices": [
#      139,
#      140
#     ],
#     "type": "photo",
#     "id": 669255922607370240,
#     "media_url": "http://pbs.twimg.com/media/CUmstzrWsAAvl-a.jpg"
#    }
#   ]
#  },
#  "in_reply_to_screen_name": null,
#  "in_reply_to_user_id": null,
#  "retweet_count": 3,
#  "id_str": "669258955160465408",
#  "favorited": false,
#  "retweeted_status": {
#   "contributors": null,
#   "truncated": false,
#   "text": "How safe is your water? FREE Audit here from Macol Consulting  https://t.co/vrKCUEEKF8  #bromsgrovehour #crypto https://t.co/Jrjm6NMlNt",
#   "is_quote_status": false,
#   "in_reply_to_status_id": null,
#   "id": 669255922674454529,
#   "favorite_count": 1,
#   "source": "<a href=\"http://bufferapp.com\" rel=\"nofollow\">Buffer</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       88,
#       103
#      ],
#      "text": "bromsgrovehour"
#     },
#     {
#      "indices": [
#       104,
#       111
#      ],
#      "text": "crypto"
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/vrKCUEEKF8",
#      "indices": [
#       63,
#       86
#      ],
#      "expanded_url": "http://bit.ly/1OquB2c",
#      "display_url": "bit.ly/1OquB2c"
#     }
#    ],
#    "media": [
#     {
#      "expanded_url": "http://twitter.com/LYNDONJJSTOKES/status/669255922674454529/photo/1",
#      "display_url": "pic.twitter.com/Jrjm6NMlNt",
#      "url": "https://t.co/Jrjm6NMlNt",
#      "media_url_https": "https://pbs.twimg.com/media/CUmstzrWsAAvl-a.jpg",
#      "id_str": "669255922607370240",
#      "sizes": {
#       "large": {
#        "h": 157,
#        "resize": "fit",
#        "w": 266
#       },
#       "small": {
#        "h": 157,
#        "resize": "fit",
#        "w": 266
#       },
#       "medium": {
#        "h": 157,
#        "resize": "fit",
#        "w": 266
#       },
#       "thumb": {
#        "h": 150,
#        "resize": "crop",
#        "w": 150
#       }
#      },
#      "indices": [
#       112,
#       135
#      ],
#      "type": "photo",
#      "id": 669255922607370240,
#      "media_url": "http://pbs.twimg.com/media/CUmstzrWsAAvl-a.jpg"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 3,
#   "id_str": "669255922674454529",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "has_extended_profile": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 2359987412,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/667319080924246017/mHJXcnJb_normal.jpg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/8GDb4JHSgT",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www.thebestof.co.uk/bromsgrove",
#        "display_url": "thebestof.co.uk/bromsgrove"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 1173,
#    "profile_sidebar_border_color": "FFFFFF",
#    "id_str": "2359987412",
#    "profile_background_color": "C0DEED",
#    "listed_count": 30,
#    "is_translation_enabled": false,
#    "utc_offset": 0,
#    "statuses_count": 11188,
#    "description": "Passionate about showcasing and promoting the very best businesses in #Bromsgrove - #thebestofbromsgrove",
#    "friends_count": 1069,
#    "location": "Bromsgrove",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/667319080924246017/mHJXcnJb_normal.jpg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/2359987412/1404141999",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "LYNDONJJSTOKES",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 81,
#    "name": "TheBestof Bromsgrove",
#    "notifications": false,
#    "url": "http://t.co/8GDb4JHSgT",
#    "created_at": "Mon Feb 24 20:21:25 +0000 2014",
#    "contributors_enabled": false,
#    "time_zone": "London",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Tue Nov 24 20:47:00 +0000 2015",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  "user": {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": false,
#   "default_profile_image": false,
#   "id": 4046332347,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "verified": false,
#   "profile_text_color": "000000",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/658638220188655616/mPbdHo2d_normal.jpg",
#   "profile_sidebar_fill_color": "000000",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/QAJgD8G86L",
#       "indices": [
#        0,
#        23
#       ],
#       "expanded_url": "http://www.macolconsulting.com",
#       "display_url": "macolconsulting.com"
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 54,
#   "profile_sidebar_border_color": "000000",
#   "id_str": "4046332347",
#   "profile_background_color": "000000",
#   "listed_count": 0,
#   "is_translation_enabled": false,
#   "utc_offset": 0,
#   "statuses_count": 65,
#   "description": "Offering: Legionella risk assessment, training & consultancy. Expert consultancy with small business service level. Please contact anytime for further info",
#   "friends_count": 170,
#   "location": "Bromsgrove, England",
#   "profile_link_color": "ABB8C2",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/658638220188655616/mPbdHo2d_normal.jpg",
#   "following": false,
#   "geo_enabled": false,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/4046332347/1445946019",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "screen_name": "MACOLConsulting",
#   "lang": "en",
#   "profile_background_tile": false,
#   "favourites_count": 19,
#   "name": "MACOL Consulting",
#   "notifications": false,
#   "url": "https://t.co/QAJgD8G86L",
#   "created_at": "Mon Oct 26 13:20:09 +0000 2015",
#   "contributors_enabled": false,
#   "time_zone": "London",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": null,
#  "possibly_sensitive": false,
#  "lang": "en",
#  "created_at": "Tue Nov 24 20:59:03 +0000 2015",
#  "in_reply_to_status_id_str": null,
#  "place": null,
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  }
# }

# %%
print type(statuses[0])
# Out:
# <type 'dict'>

# %% [markdown]
# Note: Should you desire to do so, you can load the same set of search results that are illustrated in the text of _Mining the Social Web_ by executing the code below that reads a snapshot of the data and stores it into the same statuses variable as was defined above. Alternatively, you can choose to skip execution of this cell in order to follow along with your own data.

# %%
import json
#skip this for now, use our json data
#statuses = json.loads(open('resources/ch01-twitter/data/MentionSomeoneImportantForYou.json').read())

# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = [ status 
      for status in statuses
          #if status['id'] == 316948241264549888 
    ][0]

# Explore the variable t to get familiarized with the data structure...

print t['retweet_count']
print t['retweeted_status']

# Can you find the most retweeted tweet in your search results? Try do do it!
# Out:
# 3
# {u'contributors': None, u'truncated': False, u'text': u'How safe is your water? FREE Audit here from Macol Consulting  https://t.co/vrKCUEEKF8  #bromsgrovehour #crypto https://t.co/Jrjm6NMlNt', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 669255922674454529, u'favorite_count': 1, u'source': u'<a href="http://bufferapp.com" rel="nofollow">Buffer</a>', u'retweeted': False, u'coordinates': None, u'entities': {u'symbols': [], u'user_mentions': [], u'hashtags': [{u'indices': [88, 103], u'text': u'bromsgrovehour'}, {u'indices': [104, 111], u'text': u'crypto'}], u'urls': [{u'url': u'https://t.co/vrKCUEEKF8', u'indices': [63, 86], u'expanded_url': u'http://bit.ly/1OquB2c', u'display_url': u'bit.ly/1OquB2c'}], u'media': [{u'expanded_url': u'http://twitter.com/LYNDONJJSTOKES/status/669255922674454529/photo/1', u'display_url': u'pic.twitter.com/Jrjm6NMlNt', u'url': u'https://t.co/Jrjm6NMlNt', u'media_url_https': u'https://pbs.twimg.com/media/CUmstzrWsAAvl-a.jpg', u'id_str': u'669255922607370240', u'sizes': {u'large': {u'h': 157, u'resize': u'fit', u'w': 266}, u'small': {u'h': 157, u'resize': u'fit', u'w': 266}, u'medium': {u'h': 157, u'resize': u'fit', u'w': 266}, u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}}, u'indices': [112, 135], u'type': u'photo', u'id': 669255922607370240, u'media_url': u'http://pbs.twimg.com/media/CUmstzrWsAAvl-a.jpg'}]}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 3, u'id_str': u'669255922674454529', u'favorited': False, u'user': {u'follow_request_sent': False, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 2359987412, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/667319080924246017/mHJXcnJb_normal.jpg', u'profile_sidebar_fill_color': u'DDEEF6', u'entities': {u'url': {u'urls': [{u'url': u'http://t.co/8GDb4JHSgT', u'indices': [0, 22], u'expanded_url': u'http://www.thebestof.co.uk/bromsgrove', u'display_url': u'thebestof.co.uk/bromsgrove'}]}, u'description': {u'urls': []}}, u'followers_count': 1173, u'profile_sidebar_border_color': u'FFFFFF', u'id_str': u'2359987412', u'profile_background_color': u'C0DEED', u'listed_count': 30, u'is_translation_enabled': False, u'utc_offset': 0, u'statuses_count': 11188, u'description': u'Passionate about showcasing and promoting the very best businesses in #Bromsgrove - #thebestofbromsgrove', u'friends_count': 1069, u'location': u'Bromsgrove', u'profile_link_color': u'0084B4', u'profile_image_url': u'http://pbs.twimg.com/profile_images/667319080924246017/mHJXcnJb_normal.jpg', u'following': False, u'geo_enabled': False, u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2359987412/1404141999', u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png', u'screen_name': u'LYNDONJJSTOKES', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 81, u'name': u'TheBestof Bromsgrove', u'notifications': False, u'url': u'http://t.co/8GDb4JHSgT', u'created_at': u'Mon Feb 24 20:21:25 +0000 2014', u'contributors_enabled': False, u'time_zone': u'London', u'protected': False, u'default_profile': False, u'is_translator': False}, u'geo': None, u'in_reply_to_user_id_str': None, u'possibly_sensitive': False, u'lang': u'en', u'created_at': u'Tue Nov 24 20:47:00 +0000 2015', u'in_reply_to_status_id_str': None, u'place': None, u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'}}

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print json.dumps(status_texts[0:5], indent=1)
print json.dumps(screen_names[0:5], indent=1) 
print json.dumps(hashtags[0:5], indent=1)
print json.dumps(words[0:5], indent=1)
# Out:
# [
#  "RT @LYNDONJJSTOKES: How safe is your water? FREE Audit here from Macol Consulting  https://t.co/vrKCUEEKF8  #bromsgrovehour #crypto https:/\u2026",
#  "#CrowdActivism Think #BTC! : #ITALIA URGENTE #TERRORISMO CRUCIALE INTEL #ITALIANI https://t.co/Np5IpZI93g via @censorednewsnow",
#  "RT @Kuya_Marc: I wish for #Bitcoin #donations: https://t.co/D15lzV8G4u #encouragement It is now 04:47:34PHT.",
#  "#FBI #NSA @BarackObama #security #crypto @tim_cook #Apple https://t.co/vb1t54JhYG",
#  "RT @whaleclubco: $322.39 \u00b7 Some potential harmonic patterns evolving here. Fa... https://t.co/vvPyivt0Am #bitcoin https://t.co/Dp4BdfQmeR"
# ]
# [
#  "LYNDONJJSTOKES",
#  "censorednewsnow",
#  "Kuya_Marc",
#  "BarackObama",
#  "tim_cook"
# ]
# [
#  "bromsgrovehour",
#  "crypto",
#  "CrowdActivism",
#  "BTC",
#  "ITALIA"
# ]
# [
#  "RT",
#  "@LYNDONJJSTOKES:",
#  "How",
#  "safe",
#  "is"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print c.most_common()[:10] # top 10
    print
# Out:
# [(u'#bitcoin', 328), (u'RT', 194), (u'#Bitcoin', 158), (u'to', 114), (u'the', 110), (u'Bitcoin', 108), (u'for', 95), (u'and', 91), (u'-', 84), (u'#dogecoin', 67)]
#
# [(u'cryptocointalk', 13), (u'whaleclubco', 10), (u'coindesk', 9), (u'ProTipHQ', 8), (u'FGraillot', 8), (u'chain', 7), (u'HELPS_COIN', 7), (u'MadBitcoins', 7), (u'mPAtBit', 7), (u'ProjectCoin', 7)]
#
# [(u'bitcoin', 345), (u'Bitcoin', 168), (u'dogecoin', 70), (u'crypto', 67), (u'btc', 58), (u'BTC', 58), (u'money', 56), (u'news', 54), (u'blockchain', 53), (u'love', 51)]

# %% [markdown]
# ## Example 8. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print pt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-15-766a6a42c202> in <module>()
# ----> 1 from prettytable import PrettyTable
#       2
#       3 for label, data in (('Word', words),
#       4                     ('Screen Name', screen_names),
#       5                     ('Hashtag', hashtags)):
#
# ImportError: No module named prettytable

# %% [markdown]
# ## Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print lexical_diversity(words)
print lexical_diversity(screen_names)
print lexical_diversity(hashtags)
print average_words(status_texts)
# Out:
# 0.345558739255
# 0.517520215633
# 0.178398710371
# 14.5416666667

# %% [markdown]
# ## Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if status.has_key('retweeted_status')
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print pt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c38e5fce73f0> in <module>()
#      14 # Slice off the first 5 from the sorted results and display each item in the tuple
#      15
# ---> 16 pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
#      17 [ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
#      18 pt.max_width['Text'] = 50
#
# NameError: name 'PrettyTable' is not defined

# %% [markdown]
# ## Example 11. Looking up users who have retweeted a status

# %%
# Get the original tweet id for a tweet from its retweeted_status node 
# and insert it here in place of the sample value that is provided
# from the text of the book

_retweets = twitter_api.statuses.retweets(id=317127304981667841)
print [r['user']['screen_name'] for r in _retweets]
# Out:
# [u'jyeee', u'Ceejaynatics', u'Majendalove', u'shameeennnn', u'EmilyearoRuiz', u'Oliviyaaay', u'ikaayyy_', u'RafaellaaaMae', u'LoveKyana18', u'iiaamcamillee', u'kidamgos', u'ShaaaronOng', u'asdfghjbl']

# %% [markdown]
# ## Example 12. Plotting frequencies of words

# %%
word_counts = sorted(Counter(words).values(), reverse=True)

plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-4f5b8d52ec41> in <module>()
#       1 word_counts = sorted(Counter(words).values(), reverse=True)
#       2
# ----> 3 plt.loglog(word_counts)
#       4 plt.ylabel("Freq")
#       5 plt.xlabel("Word Rank")
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Example 13. Generating histograms of words, screen names, and hashtags

# %%
for label, data in (('Words', words), 
                    ('Screen Names', screen_names), 
                    ('Hashtags', hashtags)):

    # Build a frequency map for each set of data
    # and plot the values
    c = Counter(data)
    plt.hist(c.values())
    
    # Add a title and y-label ...
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    
    # ... and display as a new figure
    plt.figure()

# %% [markdown]
# ## Example 14. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print counts

# %% [markdown]
# Note: This histogram gives you an idea of how many times tweets are retweeted with the x-axis defining partitions for tweets that have been retweeted some number of times and the y-axis telling you how many tweets fell into each bin. For example, a y-axis value of 5 for the "15-20 bin" on the x-axis means that there were 5 tweets that were retweeted between 15 and 20 times.
#
# Here's another variation that transforms the data using the (automatically imported from numpy) log function in order to improve the resolution of the plot.

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

# Taking the log of the *data values* themselves can 
# often provide quick and valuable insight into the
# underlying distribution as well. Try it back on
# Example 13 and see if it helps.

plt.hist(log(counts))
plt.title("Retweets")
plt.xlabel('Log[Bins (number of times retweeted)]')
plt.ylabel('Log[Number of tweets in bin]')

print log(counts)
