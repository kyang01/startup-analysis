# %%
# %matplotlib inline
from bs4 import BeautifulSoup
import urllib2
import urllib
import json
import csv
import time
import pickle
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
import sys
import os
import time
sns.set_style("whitegrid")
sns.set_context("poster")

# %%
def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)
    
def merge_d(x, y):
    z = x.copy()
    z.update(y)
    return z

def flatten_data(t_data):
    t_data_f= {}
    for key in t_data.keys():
        for key2 in t_data[key].keys():
            t_data_f[key + '_' + key2] = t_data[key][key2]
    return t_data_f

twit_data = flatten_data(load_obj('twit_data1'))
t_data_num = 1

def backup(obj, t_data_num = t_data_num):
    name = "t_df" + str(t_data_num)
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %%
company_l = []
series_l = []
text_l = [] 
time_l = []
retweets_l = []
likes_l = []
name_l = []
href_l = []
errors = []
max_ind = len(twit_data.keys())
start = time.time()

for i in range(max_ind):    
    if i % 50 == 0:
        mins = (time.time() - start) / 60
        print 'Percent progress ' + str(100.0 * i / max_ind) + ' running for ' + str(mins) + ' mins'          
        data_backup = {'Company': company_l, 'Series': series_l, 'Text': text_l, 'Time':time_l, 'Retweets':retweets_l, 'Likes':likes_l, 'Name':name_l, 'Href':href_l}
        backup(data_backup)
    company_series = twit_data.keys()[i]
    ind = company_series[:company_series.rfind("_")].rfind("_")
    company = company_series[:ind]
    series = company_series[ind:]
    backup({'Company': company_l, 'Series': series_l, 'Text': text_l, 'Time':time_l, 'Retweets':retweets_l, 'Likes':likes_l, 'Name':name_l, 'Href':href_l})
    for tweet in twit_data[company_series]:
        try:
            # Searching
            soup = BeautifulSoup(tweet, 'lxml')
            actions = soup.find_all('div', class_='ProfileTweet-actionCountList')[0]
            text = soup.find_all('p', class_ = 'TweetTextSize')[0].text
            times = soup.find_all('a', class_ = 'tweet-timestamp')[0].text
            retweets = actions.find_all('span', class_='ProfileTweet-actionCount')[0].text.strip()
            likes = actions.find_all('span', class_='ProfileTweet-actionCount')[1].text.strip()
            name = soup.find_all('strong', class_='fullname')[0].text
            href = soup.find_all('a', class_='account-group')[0]['href']
            
            # Storing
            company_l.append(company)
            series_l.append(series)
            text_l.append(text)
            time_l.append(times)
            retweets_l.append(retweets)
            likes_l.append(likes)
            name_l.append(name)
            href_l.append(href)
        except KeyboardInterrupt:
            try:
                sys.exit(0)
            except SystemExit:
                os._exit(0) 
        except:
            errors.append(tweet)
# Out:
# Percent progress 0.0 running for 5.08666038513e-05 mins
# Percent progress 5.0 running for 0.929983933767 mins
# Percent progress 10.0 running for 2.19964901606 mins
# Percent progress 15.0 running for 3.53876201709 mins
# Percent progress 20.0 running for 4.88092761834 mins
# Percent progress 25.0 running for 6.11316250165 mins
# Percent progress 30.0 running for 7.68281498353 mins
# Percent progress 35.0 running for 9.68449503183 mins
# Percent progress 40.0 running for 11.6382258654 mins
# Percent progress 45.0 running for 13.2810905496 mins
# Percent progress 50.0 running for 15.5552463651 mins
# Percent progress 55.0 running for 17.8359643817 mins
# Percent progress 60.0 running for 20.021214668 mins
# Percent progress 65.0 running for 22.598205018 mins
# Percent progress 70.0 running for 25.0689711491 mins
# Percent progress 75.0 running for 28.2786712845 mins
# Percent progress 80.0 running for 31.1675331672 mins
# Percent progress 85.0 running for 34.0141220649 mins
# Percent progress 90.0 running for 37.2621017337 mins
# Percent progress 95.0 running for 40.6350143154 mins

# %%
tweets = pd.read_csv(open("../tweets/tweets.csv", 'rU'), encoding='utf-8', engine='c')
tweets_translated = pd.read_csv(open("../startups/translatedTweets.csv", 'rU'), encoding='utf-8', engine='c')
tweets_translated.head()
# Out:
# /Users/candokevin/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#    Unnamed: 0 Unnamed: 0.1    Company           Href    Likes              Name    Retweets     Series                                               Text         Time
# 0           0            0  Occipital  /yehyehgluglu  0 likes        Maria Melo  0 retweets  _Series_A  @rubaums2 mira in the occipital and frontal to...  14 Jul 2011
# 1           1            2  Occipital  /ArturoMisifu  0 likes    Arturo Quijano  0 retweets  _Series_A  at the height of the occipital head - hurts if...  14 Jul 2011
# 2           2            5  Occipital     /victorcab  0 likes  Victor Caballero  0 retweets  _Series_A  Tripod – Timer for 360 Views – iPhone? : http:...  14 Jul 2011
# 3           3            7  Occipital   /electroniko  0 likes    MIGUEL NEGRETE  0 retweets  _Series_A  Neurona, glia, axon myelin, parietal, temporal...  14 Jul 2011
# 4           4            8  Occipital    /nomina_bot  0 likes              体野ミナ  0 retweets  _Series_A  Greater occipital nerve:nervus occipitalis maj...  13 Jul 2011

# %%
months = {'Jan':1, 'Feb':2, 'Mar':3, 'Apr':4, 'May':5, 'Jun':6, 'Jul':7, 'Aug':8, 'Sep':9, 'Oct':10, 'Nov':11, 'Dec':12}
time_sub = []
for row in tweets.iterrows():
    if type(row[1]['Time']) != unicode:
        time_sub.append(0)
    elif len(row[1]['Time'].split(' ')) == 3:
        if row[1]['Time'].split(' ')[1] in months.keys():        
            time_sub.append(int(row[1]['Time'].split(' ')[2]) * 365 + months[row[1]['Time'].split(' ')[1]] * 30 + int(row[1]['Time'].split(' ')[0]))
        else:
            time_sub.append(0)
    else:
        time_sub.append(0)
        
tweets['Date_Num'] = time_sub
tweets = tweets[tweets['Date_Num'] != 0]

valid_data = []
for val in zip(list((tweets.groupby(['Company', 'Series']).size() > 150).index), list((tweets.groupby(['Company', 'Series']).size() > 150).values)):
    if val[1]:
        valid_data.append(val[0])
        
valid_tweets = []
for valid_pair in valid_data:
    company = valid_pair[0]
    series = valid_pair[1]
    match_company = tweets[tweets['Company'] == company]
    valid_tweets.append(match_company[match_company['Series'] == series])

# %%
valid_tweets_pd = pd.concat(valid_tweets)
for row in tweets_translated.iterrows():
    company = row[1]['Company']
    href = row[1]['Href']
    time = row[1]['Time']

    match_comp = valid_tweets_pd[valid_tweets_pd['Company'] == company]
    match_href = match_comp[match_comp['Href'] == href]
    match_time = match_href[match_href['Time'] == time]
    
    res = list(match_time.index)
    if len(res) == 1:
        index = res[0]
        valid_tweets_pd.set_value(index, 'Text', row[1].Text)

# %%
valid_tweets_pd.to_csv('valid_tweets.csv', encoding='utf-8')

# %%
len(tweets_translated)
# Out:
# 198201

# %%
# Out:
#            Company              Href    Likes                               Name    Retweets    Series                                               Text         Time  Date_Num
# 0        Occipital     /yehyehgluglu  0 likes                         Maria Melo  0 retweets  Series_A  @rubaums2 mira no frontal  até o occipital e f...  14 Jul 2011    734239
# 1        Occipital        /occipital  0 likes                          Occipital   1 retweet  Series_A  Cats out of the bag, we're excited! RT @savvys...  14 Jul 2011    734239
# 2        Occipital     /ArturoMisifu  0 likes                     Arturo Quijano  0 retweets  Series_A  me duele la cabeza a la altura del occipital -...  14 Jul 2011    734239
# 3        Occipital          /ortidog  0 likes                         Paul White  0 retweets  Series_A  No matter what happens, I always have the Occi...  14 Jul 2011    734239
# 4        Occipital     /durlancastro  0 likes                      Durlan Castro  0 retweets  Series_A  Headaches are mostly caused by adhesions in th...  14 Jul 2011    734239
# 5        Occipital        /victorcab  0 likes                   Victor Caballero  0 retweets  Series_A  Tripod – Timer for 360 Views – iPhone? : http:...  14 Jul 2011    734239
# 6        Occipital        /tash_jade  0 likes                         a.h. sataN  0 retweets  Series_A  My occipital spatula is orbiting right now. No...  14 Jul 2011    734239
# 7        Occipital      /electroniko  0 likes                     MIGUEL NEGRETE  0 retweets  Series_A  Neurona, glia,mielina,axon,parietal,occipital,...  14 Jul 2011    734239
# 8        Occipital       /nomina_bot  0 likes                               体野ミナ  0 retweets  Series_A  大後頭神経：nervus occipitalis major/greater occipit...  13 Jul 2011    734238
# 9        Occipital         /capiendo  0 likes                       Ted Capiendo  0 retweets  Series_A                                                yay  13 Jul 2011    734238
# 10       Occipital    /DarinRMcClure  0 likes                              Darin  0 retweets  Series_A  happy happy joy joy! You can embed a @occipita...  13 Jul 2011    734238
# 11       Occipital        /occipital  0 likes                          Occipital   1 retweet  Series_A  @DarinRMcClure In fact you can with a nice js ...  13 Jul 2011    734238
# 12       Occipital    /DarinRMcClure  0 likes                              Darin  0 retweets  Series_A    I wish I could embed my 360's @occipital #SMMOC  13 Jul 2011    734238
# 13       Occipital         /jrpowers   1 like                        Jeff Powers  0 retweets  Series_A  Absinthe with @occipital/team in commemoration...  13 Jul 2011    734238
# 14       Occipital        /gingerale  0 likes                       Ginger Cohen  0 retweets  Series_A  RT @MarieSPowers An amazing panorama taken by ...  13 Jul 2011    734238
# 15       Occipital     /RepasoMedico   1 like               Dr. Ernst Gräfenberg  3 retweets  Series_A  Osteoporisis Circunscrita: fase lítica de Enf....  13 Jul 2011    734238
# 16       Occipital       /nomina_bot  0 likes                               体野ミナ  0 retweets  Series_A  外後頭隆起：protuberantia　occipitalis externa/extern...  13 Jul 2011    734238
# 17       Occipital    /Aquilla_Genny  0 likes                  Ruqhayah El Genny  0 retweets  Series_A  RT @Anda_Tahu: Otak bagian luar (korteks): mem...  13 Jul 2011    734238
# 18       Occipital       /vikasreddy  0 likes                        Vikas Reddy   1 retweet  Series_A  RT @gmcerveny Two exciting new jobs on the @oc...  13 Jul 2011    734238
# 19       Occipital         /jrpowers  0 likes                        Jeff Powers  0 retweets  Series_A  @AlexisTryon @occipital @Artsicle yeah!  check...  13 Jul 2011    734238
# 20       Occipital      /AlexisTryon  0 likes                       Alexis Tryon  0 retweets  Series_A  @jrpowers @occipital should probably chat with...  13 Jul 2011    734238
# 21       Occipital    /BlakeHamilton  0 likes                     Blake Hamilton  0 retweets  Series_A  #wordmismatchoftheday (I just made this up): O...  13 Jul 2011    734238
# 22       Occipital      /joshmishell  0 likes                       Josh Mishell  0 retweets  Series_A  @occipital nice! My only qualification is that...  13 Jul 2011    734238
# 23       Occipital        /occipital   1 like                          Occipital   1 retweet  Series_A  We're at it again. Help us push the limits of ...  13 Jul 2011    734238
# 24       Occipital       /TrishelleC  0 likes      Trishelle\nVerified account\n   1 retweet  Series_A  My job is awesome. Got to watch an occipital s...  13 Jul 2011    734238
# 25       Occipital        /skipology  0 likes                          Skipology  0 retweets  Series_A  @mikewren @occipital Hi Mike that looks great,...  13 Jul 2011    734238
# 26       Occipital  /UniversitasPsyc  0 likes                   UniversitasPsych  0 retweets  Series_A  Conduction Aphasia as a Result of Left Parieta...  13 Jul 2011    734238
# 27       Occipital         /Jai_marc  0 likes                        ✨Jaye Luces  0 retweets  Series_A  This man is goin thru some serious midlife cri...  13 Jul 2011    734238
# 28       Occipital         /serena72  0 likes                             Serena  0 retweets  Series_A  Updates: Migraines, Headache and Occipital Neu...  13 Jul 2011    734238
# 29       Occipital         /Tink_Lee  0 likes                    Nita Lee Thomas  0 retweets  Series_A   The occipital part of my brain always in pain...  13 Jul 2011    734238
# ...            ...               ...      ...                                ...         ...       ...                                                ...          ...       ...
# 387817  OvaScience    /andreafwalker  0 likes                      Andrea Walker  0 retweets  Series_D  Michelle Dipp of OvaScience leading new genera...  29 Oct 2012    734709
# 387818  OvaScience       /OvaScience  0 likes                         OvaScience  0 retweets  Series_D  Last few minutes of #ASRM2012.  Make sure to s...  24 Oct 2012    734704
# 387819  OvaScience       /resolveorg  0 likes                         resolveorg  2 retweets  Series_D  Has your doctor signed the Family Act pledge a...  22 Oct 2012    734702
# 387820  OvaScience           /PearlF  0 likes                       Pearl Freier  2 retweets  Series_D  Nice profile of Cambridge-based @ovascience & ...  22 Oct 2012    734702
# 387821  OvaScience   /STLinfertility  0 likes                  Kenan Omurtag, MD  0 retweets  Series_D  got my freedom party & @OvaScience tix... #ASR...  19 Oct 2012    734699
# 387822  OvaScience       /OvaScience  0 likes                         OvaScience   1 retweet  Series_D  OvaScience to Host Scientific Symposium at #AS...  19 Oct 2012    734699
# 387823  OvaScience          /cro_bio  0 likes                  CRO Contract Res.  0 retweets  Series_D  OvaScience to Host Scientific Symposium at 201...  18 Oct 2012    734698
# 387824  OvaScience        /BW_Health  0 likes                     BW Health News  0 retweets  Series_D  OvaScience to Host Scientific Symposium at 201...  18 Oct 2012    734698
# 387825  OvaScience            /jbyer  0 likes                         Jared Byer  0 retweets  Series_D  Michelle Dipp of OvaScience leading new genera...  16 Oct 2012    734696
# 387826  OvaScience        /preg_help  0 likes                Pregnancy Solutions  0 retweets  Series_D  Michelle Dipp CEO of OvaScience in high demand...  16 Oct 2012    734696
# 387827  OvaScience       /DaleYuzuki  0 likes                        Dale Yuzuki  0 retweets  Series_D  And OvaScience is her third startup. RT @biote...  15 Oct 2012    734695
# 387828  OvaScience       /OvaScience  0 likes                         OvaScience  0 retweets  Series_D  OvaScience highlighted in today's Boston Globe...  14 Oct 2012    734694
# 387829  OvaScience     /ScottKirsner   1 like  Scott Kirsner\nVerified account\n  6 retweets  Series_D  1st of a new generation of biotech CEOs in Cam...  14 Oct 2012    734694
# 387830  OvaScience  /charliemarquard   1 like                  Charlie Marquardt  0 retweets  Series_D  Nice piece on East #CambMA Biotech #OvaScience...  14 Oct 2012    734694
# 387831  OvaScience         /JS_Lacey  0 likes                         John Lacey  0 retweets  Series_D  Grt @ScottKirsner article on my friend @michel...  14 Oct 2012    734694
# 387832  OvaScience   /BullConsulting  0 likes                The Bull Consulting  0 retweets  Series_D  INNOVATION ECONOMYMichelle Dipp, 36, reflects ...  14 Oct 2012    734694
# 387833  OvaScience   /STLinfertility  0 likes                  Kenan Omurtag, MD   1 retweet  Series_D  @OvaScience, got my seat to tuesday night dinn...  12 Oct 2012    734692
# 387834  OvaScience         /dankaser  0 likes                 Daniel Kaser, M.D.  0 retweets  Series_D  One step closer: @sciencemagazine @OvaScience ...   8 Oct 2012    734688
# 387835  OvaScience   /STLinfertility  0 likes                  Kenan Omurtag, MD  0 retweets  Series_D  Thanks for re tweet @ReprodMed, looking for he...   3 Oct 2012    734683
# 387836  OvaScience   /STLinfertility  0 likes                  Kenan Omurtag, MD   1 retweet  Series_D  my program director is speaking @ReprodMed 201...   2 Oct 2012    734682
# 387837  OvaScience     /HealthVCFeed  0 likes                     Health VC Feed  0 retweets  Series_D  Sunovion, Ironwood, OvaScience, & More Boston ...  30 Sep 2012    734680
# 387838  OvaScience     /RAPS_Careers  0 likes                       RAPS_Careers  0 retweets  Series_D  Quality Assurance Coordinator | OvaScience: US...  26 Sep 2012    734676
# 387839  OvaScience       /OvaScience  0 likes                         OvaScience  0 retweets  Series_D  OvaScience to Present at UBS Global Life Scien...  19 Sep 2012    734669
# 387840  OvaScience          /bioexec  0 likes                            BioExec  0 retweets  Series_D  "Ovascience is a remarkable IPO and the first ...  13 Sep 2012    734663
# 387841  OvaScience    /hospitalITjob  0 likes                      hospitalITjob  0 retweets  Series_D  Senior Research Associate/Research AssociateSe...  12 Sep 2012    734662
# 387842  OvaScience       /OvaScience  0 likes                         OvaScience   1 retweet  Series_D  OvaScience to present today:  http://www.marke...  11 Sep 2012    734661
# 387843  OvaScience    /BioPharmaJosh  0 likes                        Josh Berlin  0 retweets  Series_D  Pink Sheet Daily: Financings Of The Fortnight ...   7 Sep 2012    734657
# 387844  OvaScience       /OvaScience  0 likes                         OvaScience   1 retweet  Series_D  OvaScience to Present at Upcoming 2012 Investo...   7 Sep 2012    734657
# 387845  OvaScience         /cynthfox  0 likes                           cynthfox  0 retweets  Series_D  OvaScience to Present at the Stifel Nicolaus 2...   6 Sep 2012    734656
# 387846  OvaScience      /News_Pharma  0 likes                        Pharma News  0 retweets  Series_D  Intercept and OvaScience file for IPOs to prog...   5 Sep 2012    734655
#
# [370944 rows x 9 columns]

# %%
tweets[tweets['Company'] == company].head(10)
# Out:
#      Company           Href    Likes              Name    Retweets    Series                                               Text         Time  Date_Num
# 0  Occipital  /yehyehgluglu  0 likes        Maria Melo  0 retweets  Series_A  @rubaums2 mira no frontal  até o occipital e f...  14 Jul 2011    734239
# 1  Occipital     /occipital  0 likes         Occipital   1 retweet  Series_A  Cats out of the bag, we're excited! RT @savvys...  14 Jul 2011    734239
# 2  Occipital  /ArturoMisifu  0 likes    Arturo Quijano  0 retweets  Series_A  me duele la cabeza a la altura del occipital -...  14 Jul 2011    734239
# 3  Occipital       /ortidog  0 likes        Paul White  0 retweets  Series_A  No matter what happens, I always have the Occi...  14 Jul 2011    734239
# 4  Occipital  /durlancastro  0 likes     Durlan Castro  0 retweets  Series_A  Headaches are mostly caused by adhesions in th...  14 Jul 2011    734239
# 5  Occipital     /victorcab  0 likes  Victor Caballero  0 retweets  Series_A  Tripod – Timer for 360 Views – iPhone? : http:...  14 Jul 2011    734239
# 6  Occipital     /tash_jade  0 likes        a.h. sataN  0 retweets  Series_A  My occipital spatula is orbiting right now. No...  14 Jul 2011    734239
# 7  Occipital   /electroniko  0 likes    MIGUEL NEGRETE  0 retweets  Series_A  Neurona, glia,mielina,axon,parietal,occipital,...  14 Jul 2011    734239
# 8  Occipital    /nomina_bot  0 likes              体野ミナ  0 retweets  Series_A  大後頭神経：nervus occipitalis major/greater occipit...  13 Jul 2011    734238
# 9  Occipital      /capiendo  0 likes      Ted Capiendo  0 retweets  Series_A                                                yay  13 Jul 2011    734238

# %%
  
valid_tweets_pd = pd.concat(valid_tweets)
valid_tweets_pd['Likes'] = valid_tweets_pd.apply(lambda row: int(row['Likes'][0]), axis=1)
valid_tweets_pd['Retweets'] = valid_tweets_pd.apply(lambda row: int(row['Retweets'][0]), axis=1)

# %%
days = valid_tweets_pd.groupby(['Company', 'Series'])['Date_Num'].max() - valid_tweets_pd.groupby(['Company', 'Series'])['Date_Num'].min()
tweets = valid_tweets_pd.groupby(['Company', 'Series']).size()
avg_tweets = tweets / days
total_likes= valid_tweets_pd.groupby(['Company', 'Series'])['Likes'].sum()
total_retweets = valid_tweets_pd.groupby(['Company', 'Series'])['Retweets'].sum()
companies = [val[0] for val in list(tweets.index)]
series = [val[1] for val in list(tweets.index)]
tweet_features = pd.DataFrame({'Index': range(1, 1+len(days)), 'Company':companies, 'Series':series, 'Total_Likes': total_likes, 'Total_Retweets': total_retweets, 'Avg_Tweets': avg_tweets})
tweet_features.index = range(1, 1+len(days))
funding_df=pd.read_csv("funding_collapsed.csv")
funding_df = funding_df.drop(['Unnamed: 0'], 1)
funding_df.rename(columns={'Names':'Company', 'Series_Type':'Series'}, inplace=True)
funding_df.head()
regress_features = pd.merge(tweet_features, funding_df, how='left', on=['Company', 'Series'])
regress_features = regress_features.drop('Index', 1)
regress_features = regress_features[([type(amount) == str for amount in list(regress_features.Series_Amount)])]
regress_features['Series_Amount'] = regress_features.apply(lambda row: int(row['Series_Amount'][1:].replace(',','')), axis=1)
regress_features.head()
regress_features.to_csv('regress_features.csv')
